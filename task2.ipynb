# %% [markdown]
# ### Задача 1

# %%
from math import sqrt
 
# Запрашиваем координаты X, Y, Z
x = float(input('X = '))
y = float(input('Y = '))
z = float(input('Z = '))
 
# Вычисляем длину вектора
lvec = math.sqrt(x **2 + y **2 + z **2)
 
# Выводим длину вектора
print('Length = ', lvec)
# Out:
# X = 10
# Y = 10
# Z = 0
# Length =  14.142135623730951

# %% [markdown]
# ### Задача 3

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# построение окружности

# %%
import matplotlib.pyplot as plt 
circle1=plt.Circle((0.4,0.4),.2,color='r') 
plt.gcf().gca().add_artist(circle1)

# %% [markdown]
# построение гиперболы

# %%
import matplotlib.pyplot as plt
import decimal
import numpy as np

xmin = -10
xmax = 10
dx = 0.1

xlist = np.around(np.arange(xmin, xmax, dx), decimals=4)

ylist = 1 / xlist

plt.plot(xlist, ylist)
plt.show()
# Out:
# C:\Users\Fujitsu\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: RuntimeWarning: divide by zero encountered in true_divide
#   # This is added back by InteractiveShellApp.init_path()

# %% [markdown]
# построение эллипса

# %%
from matplotlib.patches import Ellipse

plt.figure()
ax = plt.gca()

ellipse = Ellipse(xy=(0.5, 0.4), width=0.7, height=0.4, 
                        edgecolor='r', fc='None', lw=2)
ax.add_patch(ellipse)

# %% [markdown]
# ##### Задание 5

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
x = np.linspace(-5,5,50)
y = np.linspace(-5,5,50)
X,Y = np.meshgrid(x,y)
Z=(5*X - 6*Y - 8)/(-7)
Z1=(5*X - 6*Y)/(-7)
surf = ax.plot_surface(X, Y, Z)
fig = plt.figure()
ax = fig.gca(projection='3d')
surf = ax.plot_surface(X, Y, Z)
surf1 = ax.plot_surface(X, Y, Z1)
